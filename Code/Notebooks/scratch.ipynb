# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.ticker import MaxNLocator
from cycler import cycler

import numpy as np
import pandas as pd

pd.set_option('display.max_columns', 30)
plt.style.use('../../publication-guidelines/Code/tempus.mplstyle')

# %% [markdown]
# **Read in PTS and archive**

# %%
df1 = pd.read_csv('../Data/PTS_01_18_22.tsv', sep='\t', header=1)
print(df1.shape)
df2 = pd.read_csv('../Data/PTS_archive_01_18_22.tsv', sep='\t', header=1)
print(df2.shape)
# df3 = pd.read_csv('../Data/PTS_archive_rejcted_01_06_21.tsv', sep='\t', header=1)
# print(df3.shape)
df = pd.concat([df1, df2])
print(df.shape)
df.reset_index(drop=True, inplace=True)

cols_to_fill = ['Date of Most Recent Resubmission (Yr, Quarter)',
                'Date Actual Submission Occurred (Yr, Quarter, Date)',
                'Year Quarter of Publication']
for col in cols_to_fill:
    df[col] = df[col].fillna('')
    
###Remove acknowledged work
# df = df[df['Authorship Lead'].isin(['Tempus 1st &/or Last Author', 'Collab 1st and Last Author (Tempus Authored)'])]
print(df.shape)
    
df.head()
# Out:
# (162, 37)
# (185, 37)
# (347, 37)
# (347, 37)
#                Publication Stage       Manuscript Pipeline  \
# 0  Stage 6: Publication Accepted  Topic / Project-specific
# 1  Stage 6: Publication Accepted  Topic / Project-specific
# 2  Stage 6: Publication Accepted  Topic / Project-specific
# 3  Stage 6: Publication Accepted  Topic / Project-specific
# 4           Stage 5: In Revision  Topic / Project-specific
#
#                                Disclosure Categories  \
# 0  1b.  Authored peer-reviewed article in mid tie...
# 1                       2b.  Tempus authored Posters
# 2                       2b.  Tempus authored Posters
# 3  1b.  Authored peer-reviewed article in mid tie...
# 4  1b.  Authored peer-reviewed article in mid tie...
#
#                                 Authorship Lead Idea Origin      Product  \
# 0  Collab 1st and Last Author (Tempus Authored)    External           xT
# 1                   Tempus 1st &/or Last Author    Internal   AI - Other
# 2                   Tempus 1st &/or Last Author    Internal   AI - Other
# 3  Collab 1st and Last Author (Tempus Authored)    External  Algos - HRD
# 4  Collab 1st and Last Author (Tempus Authored)    External          RNA
#
#                                     Title/Topic/Link Publication Type  \
# 0  Crizotinib in patients with tumors harboring A...       manuscript
# 1  Effects of Color Calibration via ICC Profile o...         abstract
# 2  Deep Learning Identifies Microsatellite Instab...         abstract
# 3  Harmonizing on the Definition of Homologous Re...       manuscript
# 4  Redefining tumor classification and clinical s...       manuscript
#
#   Disclosure Type Detail                     Study Type  \
# 0       research article               Clinical Utility
# 1                 poster  Research/Discovery Foundation
# 2                 poster  Research/Discovery Foundation
# 3       research article  Research/Discovery Foundation
# 4       research article  Research/Discovery Foundation
#
#                                       Tempus Lead(s)  \
# 0  Kevin White, David King, Naveen Malik, Bob Tel...
# 1                                     Kshitij Ingale
# 2                                        Rohan Joshi
# 3       Alain Silk, Jerod Parsons, and Nike Beaubier
# 4                                   Ameen Salahudeen
#
#   SciComm Lead / Point Person  \
# 0            pp: Matthew Kase
# 1            Adam Hockenberry
# 2            Adam Hockenberry
# 3               pp: Alex Bobe
# 4            pp: Matthew Kase
#
#                                       Tempus Authors        Last Author  \
# 0  Kevin White, David King, Naveen Malik, Bob Tel...  Keith T. Flaherty
# 1  Kshitij Ingale; Rohan Joshi; Irvin Ho; Aicha B...      Martin Stumpe
# 2  Rohan Joshi; Andrew Kruger; Elle Moore; Ryan J...      Martin Stumpe
# 3       Alain Silk, Jerod Parsons, and Nike Beaubier       Mark Stewart
# 4            Sonal Khare, Ameen Salahudeen, Tim Rand       Ashiq Masood
#
#       External Collaborator (PI and Institution)  ...  \
# 0                    Keith T. Flaherty - NIH/NCI  ...
# 1                                            NaN  ...
# 2                                            NaN  ...
# 3      Mark Stewart - Friends of Cancer Research  ...
# 4  Ashiq Masood - Rush University Medical Center  ...
#
#   Date of Most Recent Resubmission (Yr, Quarter) Date of Publication (Date)  \
# 0                                                   (2021 Q3 9/30 Accepted)
# 1                                                        (2021 Q4 Accepted)
# 2                                                        (2021 Q4 Accepted)
# 3                                                       (2021 Q4 Accepted)
# 4                                                                       NaN
#
#   Year Quarter of Publication            Cancer Type Disease Area  \
# 0                              Multiple cancer types     Oncology
# 1                              Multiple cancer types          NaN
# 2                              Multiple cancer types     Oncology
# 3                                                NaN     Oncology
# 4                                  Colorectal cancer     Oncology
#
#          CLQ data usage      LENS Usage              IRB IRB Protocol No.  \
# 0  No CLQ data included  No LENS usage   No IRB Required              NaN
# 1     CLQ data included  No LENS usage   No IRB Required              NaN
# 2  No CLQ data included  No LENS usage   No IRB Required              NaN
# 3  No CLQ data included  No LENS usage   No IRB Required              NaN
# 4  No CLQ data included  No LENS usage   No IRB Required              NaN
#
#      IP/Legal Main Org Work Derived From  DOI PMID  \
# 0  Contacted                         R&D  NaN  NaN
# 1  Contacted                         R&D  NaN  NaN
# 2  Contacted                         R&D  NaN  NaN
# 3  Contacted             Medical Science  NaN  NaN
# 4  Contacted                         R&D  NaN  NaN
#
#   Published Info Uploaded to Website  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
#                                                Notes
# 0  Originally submitted to Annals of Oncology but...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Rejected from: Cell Reports, Cancer Cell, and Gut
#
# [5 rows x 37 columns]

# %%
df['Main Org Work Derived From'].value_counts()
# Out:
# R&D                         115
# Medical Affairs              93
# Medical Science              24
# acknowlegement - unknown      9
# Acknowlegement - Unknown      7
# Therapies                     4
# Pharma                        3
# Sales                         2
# Medical Affairs/Sales         1
# Name: Main Org Work Derived From, dtype: int64

# %% [markdown]
# # Extract (re-)submission quarters

# %%
renaming_dict = {'Title/Topic/Link': 'Title',
                'Origin (internal vs. external)': 'Origin',
                'Key BU Stakeholder Publication Supports': 'Stakeholder'}


    
cols_to_keep = ['Title/Topic/Link',
              'Authorship Lead',
              'Publication Type',
              'Main Org Work Derived From',
              'Tempus Lead(s)']

tiny_df = df[cols_to_keep].copy()
tiny_df.rename(columns=renaming_dict, inplace=True)
print(tiny_df.shape)
tiny_df.head()
# Out:
# (347, 5)
#                                                Title  \
# 0  Crizotinib in patients with tumors harboring A...
# 1  Effects of Color Calibration via ICC Profile o...
# 2  Deep Learning Identifies Microsatellite Instab...
# 3  Harmonizing on the Definition of Homologous Re...
# 4  Redefining tumor classification and clinical s...
#
#                                 Authorship Lead Publication Type  \
# 0  Collab 1st and Last Author (Tempus Authored)       manuscript
# 1                   Tempus 1st &/or Last Author         abstract
# 2                   Tempus 1st &/or Last Author         abstract
# 3  Collab 1st and Last Author (Tempus Authored)       manuscript
# 4  Collab 1st and Last Author (Tempus Authored)       manuscript
#
#   Main Org Work Derived From  \
# 0                        R&D
# 1                        R&D
# 2                        R&D
# 3            Medical Science
# 4                        R&D
#
#                                       Tempus Lead(s)
# 0  Kevin White, David King, Naveen Malik, Bob Tel...
# 1                                     Kshitij Ingale
# 2                                        Rohan Joshi
# 3       Alain Silk, Jerod Parsons, and Nike Beaubier
# 4                                   Ameen Salahudeen

# %%
###Chooose the quarters we want to care about
all_quarters = []
for year in ['2020', '2021']:
    for quarter in ['Q1', 'Q2', 'Q3', 'Q4']:
        all_quarters.append('{} {}'.format(year, quarter))

# %%
###Make some new clean columns
tiny_df['Submission_status'] = ''
tiny_df['Resubmission_status'] = ''
tiny_df['Publication_status'] = ''
tiny_df['Submission_quarter'] = ''
tiny_df['Resubmission_quarter'] = ''
tiny_df['Publication_quarter'] = ''

###Iterate throught the quarters that I care about
for quarter in all_quarters:
    print(quarter)
    ###################################################################
    ###Select the lines that were published this quarter
    temp_df = df[df['Year Quarter of Publication'].isnull()==False]
    temp_df = temp_df[(temp_df['Year Quarter of Publication'].str.contains(quarter))]
    indices = [i for i in temp_df.index if i in tiny_df.index]
    ###And set values in my tiny_df
    tiny_df.at[indices, 'Publication_status'] = 'Published'
    tiny_df.at[indices, 'Publication_quarter'] = quarter
    ###################################################################
    ###Now select the lines that were submitted (OR re-submitted) this quarter
    temp_df = df[(df['Date Actual Submission Occurred (Yr, Quarter, Date)'].str.contains(quarter))]
    indices = [i for i in temp_df.index if i in tiny_df.index]
    ###And update these values as well
    tiny_df.at[indices, 'Submission_status'] = 'Submitted'
    tiny_df.at[indices, 'Submission_quarter'] = quarter
    
    ###################################################################
    ###Now select the lines that were submitted (OR re-submitted) this quarter
    temp_df = df[(df['Date of Most Recent Resubmission (Yr, Quarter)'].str.contains(quarter))]
    indices = [i for i in temp_df.index if i in tiny_df.index]
    ###And update these values as well
    tiny_df.at[indices, 'Resubmission_status'] = 'Submitted'
    tiny_df.at[indices, 'Resubmission_quarter'] = quarter
            
    
# ###Limit my tiny dataframe to only care about projects that were either submitted or published
# tiny_df = tiny_df[(tiny_df['Submission_status']=='Submitted') |\
#                   (tiny_df['Resubmission_status']=='Submitted') |\
#                   (tiny_df['Publication_status']=='Published')]
# print(tiny_df.shape)
# tiny_df.head()
# Out:
# 2020 Q1
# 2020 Q2
# 2020 Q3
# 2020 Q4
# 2021 Q1
# 2021 Q2
# 2021 Q3
# 2021 Q4

# %%
# quarters = ['2020 Q1', '2020 Q2', '2020 Q3', '2020 Q4']
# quarters = ['2021 Q1', '2021 Q2', '2021 Q3', '2021 Q4']
quarters = ['2021 Q4']

tempy = df[(tiny_df['Submission_quarter'].isin(quarters) | tiny_df['Resubmission_quarter'].isin(quarters)) &\
       tiny_df['Main Org Work Derived From'].str.contains('Medical')]
print(tempy.shape)
# tempy[tempy['Publication Type']=='abstract'].to_clipboard()
tempy[tempy['Publication Type']=='manuscript'].to_clipboard()
# tempy.head()
# Out:
# (11, 37)

# %%
tempy
# Out:
#                       Publication Stage  \
# 7        Stage 4: Publication Submitted
# 14                 Stage 5: In Revision
# 17       Stage 4: Publication Submitted
# 23        Stage 6: Publication Accepted
# 24        Stage 6: Publication Accepted
# 25        Stage 6: Publication Accepted
# 26       Stage 4: Publication Submitted
# 34       Stage 4: Publication Submitted
# 36       Stage 4: Publication Submitted
# 37                   Stage -3: Rejected
# 67  Stage 2: Publication in Development
#
#                           Manuscript Pipeline  \
# 7          External Research: KOL Development
# 14                   External Research: Other
# 17         External Research: KOL Development
# 23  External Research: Discovery Data-Sharing
# 24  External Research: Discovery Data-Sharing
# 25  External Research: Discovery Data-Sharing
# 26  External Research: Discovery Data-Sharing
# 34         External Research: KOL Development
# 36                   External Research: Other
# 37                   External Research: Other
# 67                   External Research: Other
#
#                                 Disclosure Categories  \
# 7   1b.  Authored peer-reviewed article in mid tie...
# 14  1b.  Authored peer-reviewed article in mid tie...
# 17  1b.  Authored peer-reviewed article in mid tie...
# 23                       2b.  Tempus authored Posters
# 24                       2b.  Tempus authored Posters
# 25                       2b.  Tempus authored Posters
# 26                                                NaN
# 34                                                NaN
# 36                                                NaN
# 37  1a.  Authored peer-reviewed article in top tie...
# 67                                                NaN
#
#                                  Authorship Lead Idea Origin      Product  \
# 7   Collab 1st and Last Author (Tempus Authored)    External       xT, xF
# 14  Collab 1st and Last Author (Tempus Authored)    External           xT
# 17  Collab 1st and Last Author (Tempus Authored)    External          RNA
# 23  Collab 1st and Last Author (Tempus Authored)    External  Algos - HRD
# 24  Collab 1st and Last Author (Tempus Authored)    External           xT
# 25  Collab 1st and Last Author (Tempus Authored)    External           xT
# 26  Collab 1st and Last Author (Tempus Authored)    External           xT
# 34  Collab 1st and Last Author (Tempus Authored)    External          RNA
# 36  Collab 1st and Last Author (Tempus Authored)    External           xT
# 37                   Tempus 1st &/or Last Author    Internal           xT
# 67  Collab 1st and Last Author (Tempus Authored)    External           xT
#
#                                      Title/Topic/Link Publication Type  \
# 7   Clinicopathological characteristics of KRAS G1...       manuscript
# 14                NTRK gene fusions in thyroid cancer       manuscript
# 17  Clinical, genomic and transcriptomic data prof...       manuscript
# 23  Interrelation of Functional Homologous Recombi...         abstract
# 24  Actionable genomic landscapes from a real-worl...         abstract
# 25  Renal cell carcinoma (RCC) metastatic to pancr...         abstract
# 26  Actionable genomic landscapes from a real-worl...         abstract
# 34  Comprehensive genomic and transcriptomic profi...         abstract
# 36  Multi-institutional study of the incidence, ge...       manuscript
# 37  Rate of germline findings detected during NGS ...       manuscript
# 67  An NTRK-1 associated soft tissue tumor showing...       manuscript
#
#    Disclosure Type Detail                     Study Type  \
# 7        research article  Research/Discovery Foundation
# 14       research article  Research/Discovery Foundation
# 17       research article  Research/Discovery Foundation
# 23                 poster  Research/Discovery Foundation
# 24                 poster  Research/Discovery Foundation
# 25                 poster  Research/Discovery Foundation
# 26                    NaN  Research/Discovery Foundation
# 34                    NaN  Research/Discovery Foundation
# 36       research article               Clinical Utility
# 37       research article  Research/Discovery Foundation
# 67            case report               Clinical Utility
#
#                                        Tempus Lead(s)  \
# 7                                     Sherif El-Refai
# 14                                         Arya Ashok
# 17                       Sherif El-Refai / Denise Lau
# 23                                    Sherif El Refai
# 24                                          Greg Call
# 25                                         Arya Ashok
# 26                                          Greg Call
# 34  Josh SK Bell, Kristiyana Kaneva, Brooke Rhead,...
# 36                                  Kristiyana Kaneva
# 37                          Arya Ashok, Jessica Stoll
# 67                                        Kayla Viets
#
#         SciComm Lead / Point Person  \
# 7   Matthew Kase / Adam Hockenberry
# 14           pp: Vanessa Nepomuceno
# 17                 Adam Hockenberry
# 23                 Adam Hockenberry
# 24                 Adam Hockenberry
# 25                 Adam Hockenberry
# 26                 Adam Hockenberry
# 34                     Matthew Kase
# 36                    pp: Alex Bobe
# 37               Vanessa Nepomuceno
# 67               Vanessa Nepomuceno
#
#                                        Tempus Authors           Last Author  \
# 7            Sherif El-Refai, Prerna Jain, Denise Lau         Mohamed Salem
# 14                                         Arya Ashok         Hyunseok Kang
# 17  Prerna Jain, Denise Lau, Sherif El-Refai,  Ada...         Mark Yarchoan
# 23  Benjamin Leibowitz, Elizabeth Mauer, Sherif El...             Jason Zhu
# 24                         Elizabeth Mauer, Greg Call         Solomon Woldu
# 25          Elizabeth Mauer, Alex Barrett, Arya Ashok             Ali Khaki
# 26                         Elizabeth Mauer, Greg Call         Solomon Woldu
# 34  Josh SK Bell, Kristiyana Kaneva, Brooke Rhead,...         Funmi Olopade
# 36                                  Kristiyana Kaneva       Karen D. Wright
# 37         Arya Ashok, Jessica Stoll, Elizabeth Mauer  Funda Meric-Bernstam
# 67                          Kayla Viets, Alex Barrett          Simon Warren
#
#            External Collaborator (PI and Institution)  ...  \
# 7                                 Mohamed Salem - LCI  ...
# 14                               Hyunseok Kang - UCSF  ...
# 17  Mark Yarchoan - Johns Hopkins University, Kabi...  ...
# 23                            Levin Cancer Insititute  ...
# 24                                               UTSW  ...
# 25                                           Stanford  ...
# 26                                               UTSW  ...
# 34                                   Olopade - U of C  ...
# 36  Karen D. Wright - Boston Children’s Cancer and...  ...
# 37  Timothy Yap and Funda Meric-Bernstam - MD Ande...  ...
# 67                                                NaN  ...
#
#    Date of Most Recent Resubmission (Yr, Quarter) Date of Publication (Date)  \
# 7                                 2021 Q4 11/1/21                        NaN
# 14                                                                       NaN
# 17                                                                       NaN
# 23                                                       (2021 Q4 Accepted)
# 24                                                       (2021 Q4 Accepted)
# 25                                                       (2021 Q4 Accepted)
# 26                                                                       NaN
# 34                                                                       NaN
# 36                                                                       NaN
# 37                                                                       NaN
# 67                                                                       NaN
#
#    Year Quarter of Publication                             Cancer Type  \
# 7                                                Multiple cancer types
# 14                              Reproductive or hormone-related cancer
# 17                                                Biliary tract cancer
# 23                                                     Prostate cancer
# 24                              Reproductive or hormone-related cancer
# 25                                                               Other
# 26                              Reproductive or hormone-related cancer
# 34                                                       Breast cancer
# 36                                                               Other
# 37                                               Multiple cancer types
# 67                                                               Other
#
#    Disease Area        CLQ data usage  \
# 7      Oncology  No CLQ data included
# 14     Oncology  No CLQ data included
# 17     Oncology  No CLQ data included
# 23     Oncology  No CLQ data included
# 24     Oncology  No CLQ data included
# 25     Oncology  No CLQ data included
# 26     Oncology                   NaN
# 34     Oncology                   NaN
# 36     Oncology  No CLQ data included
# 37     Oncology  No CLQ data included
# 67     Oncology  No CLQ data included
#
#                                   LENS Usage  \
# 7   LENS cohort selection & partial analysis
# 14  LENS cohort selection & partial analysis
# 17                            No LENS usage
# 23  LENS cohort selection & partial analysis
# 24  LENS cohort selection & partial analysis
# 25  LENS cohort selection & partial analysis
# 26                                       NaN
# 34                                       NaN
# 36                            No LENS usage
# 37                            No LENS usage
# 67                            No LENS usage
#
#                                           IRB IRB Protocol No.  \
# 7                             No IRB Required              NaN
# 14                            No IRB Required              NaN
# 17                                        NaN              NaN
# 23                            No IRB Required              NaN
# 24                            No IRB Required              NaN
# 25                            No IRB Required              NaN
# 26                                        NaN              NaN
# 34                                        NaN              NaN
# 36  Covered under external collaborator's IRB              NaN
# 37     Covered under IRB Protocol - Exemption      Pro00042950
# 67                                        NaN              NaN
#
#               IP/Legal Main Org Work Derived From  DOI PMID  \
# 7           Contacted             Medical Affairs  NaN  NaN
# 14       Not contacted            Medical Affairs  NaN  NaN
# 17          Contacted             Medical Affairs  NaN  NaN
# 23          Contacted             Medical Affairs  NaN  NaN
# 24          Contacted             Medical Affairs  NaN  NaN
# 25          Contacted             Medical Affairs  NaN  NaN
# 26          Contacted             Medical Affairs  NaN  NaN
# 34                 NaN            Medical Affairs  NaN  NaN
# 36  Contacted - No IP             Medical Affairs  NaN  NaN
# 37          Contacted             Medical Affairs  NaN  NaN
# 67       Not contacted            Medical Affairs  NaN  NaN
#
#    Published Info Uploaded to Website  \
# 7                                 NaN
# 14                                NaN
# 17                                NaN
# 23                                NaN
# 24                                NaN
# 25                                NaN
# 26                                NaN
# 34                                NaN
# 36                                NaN
# 37                                NaN
# 67                                NaN
#
#                                                 Notes
# 7                                                 NaN
# 14  previous rejected submissions to Cancer (Sept ...
# 17  Originally submitted to JITC, then Cancer Immu...
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 34            Control/tracking number: 22-A-5049-AACR
# 36                                                NaN
# 37  ASCO '21 conversion 11/2021 - Reject from JAMA...
# 67                                                NaN
#
# [11 rows x 37 columns]

# %%
tempy = df[(df['Publication Stage'].isin(['Stage 1: Publication Idea Approved by Dept. Head', 'Stage 2: Publication in Development'])) &\
       (df['Main Org Work Derived From'].str.contains('Medical'))]

# %%
df[(df['Year Quarter of Publication']=='2021 Q4')& (df['Publication Type'] == 'manuscript')][[
    'Title/Topic/Link',
    'Disclosure Categories',
    'Authorship Lead',
    'Publication Type',
    'Year Quarter of Publication'
]]
# Out:
#                                       Title/Topic/Link  \
# 162  Validation of Genomic and Transcriptomic Model...
# 174  Viral dynamics of SARS-CoV-2 variants in vacci...
# 176  Systematic Review and Meta-Analysis of L-Methy...
# 187  Mouse-INtraDuctal (MIND): an in vivo model for...
# 188  Clinical outcomes and longitudinal circulating...
# 190  Review of the genomic landscape of common pedi...
# 191  rECHOmmend: an ECG-based machine-learning appr...
#
#                                  Disclosure Categories  \
# 162                                      3.  Pre-print
# 174  1a.  Authored peer-reviewed article in top tie...
# 176  1b.  Authored peer-reviewed article in mid tie...
# 187                   3.  Acknowledged/Tempus utilized
# 188                   3.  Acknowledged/Tempus utilized
# 190  1c.  Authored peer-reviewed article in lower t...
# 191                                      3.  Pre-print
#
#                                   Authorship Lead Publication Type  \
# 162                   Tempus 1st &/or Last Author       manuscript
# 174  Collab 1st and Last Author (Tempus Authored)       manuscript
# 176  Collab 1st and Last Author (Tempus Authored)       manuscript
# 187          Tempus acknowledged or services used       manuscript
# 188          Tempus acknowledged or services used       manuscript
# 190           Tempus Employee (unaffiliated work)       manuscript
# 191  Collab 1st and Last Author (Tempus Authored)       manuscript
#
#     Year Quarter of Publication
# 162                     2021 Q4
# 174                     2021 Q4
# 176                     2021 Q4
# 187                     2021 Q4
# 188                     2021 Q4
# 190                     2021 Q4
# 191                     2021 Q4

# %%
df[(df['Year Quarter of Publication']=='2021 Q4')& (df['Publication Type'] == 'abstract')][[
    'Title/Topic/Link',
    'Disclosure Categories',
    'Authorship Lead',
    'Publication Type',
    'Year Quarter of Publication',
    'Disclosure Type Detail',
    'Journal / Conference'
]].to_clipboard()

# %%
df.columns
# Out:
# Index(['Publication Stage', 'Manuscript Pipeline', 'Disclosure Categories',
#        'Authorship Lead', 'Idea Origin', 'Product', 'Title/Topic/Link',
#        'Publication Type', 'Disclosure Type Detail', 'Study Type',
#        'Tempus Lead(s)', 'SciComm Lead / Point Person', 'Tempus Authors',
#        'Last Author', 'External Collaborator (PI and Institution)',
#        'Exec. Sponsor / Department Head',
#        'Key BU Stakeholder Publication Supports', 'Business Purpose',
#        'Journal / Conference', 'Journal Impact Factor (JIF)',
#        'Date of Target Submission (Yr, Quarter, Date)',
#        'Date Actual Submission Occurred (Yr, Quarter, Date)',
#        'Date of Most Recent Resubmission (Yr, Quarter)',
#        'Date of Publication (Date)', 'Year Quarter of Publication',
#        'Cancer Type', 'Disease Area', 'CLQ data usage', 'LENS Usage', 'IRB',
#        'IRB Protocol No.', 'IP/Legal', 'Main Org Work Derived From', 'DOI',
#        'PMID', 'Published Info Uploaded to Website', 'Notes'],
#       dtype='object')

# %%
df[(df['Date Actual Submission Occurred (Yr, Quarter, Date)'].str.contains('2021 Q4') )& (df['Publication Type'] == 'abstract')][[
    'Title/Topic/Link',
    'Disclosure Categories',
    'Authorship Lead',
    'Publication Type',
    'Year Quarter of Publication',
    'Disclosure Type Detail',
    'Journal / Conference'
]].to_clipboard()
